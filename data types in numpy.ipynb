# %%
import numpy as np
arr = np.array([1,2,3,4,6,8])
print(arr.dtype)
# Out:
# int64

# %%
arr.astype("float32")
# Out:
# array([1., 2., 3., 4., 6., 8.], dtype=float32)

# %%
arr.nbytes
# Out:
# 48

# %%
arrs = np.array(['mango','banana','grapes'],dtype = 'U10')
print(arrs)
# Out:
# ['mango' 'banana' 'grapes']

# %%
arrc = np.array([1+2j,4+7j,3+3j])
print(arrc.dtype)
# Out:
# complex128
